# %% [markdown]
# ## Assignment on CSV File

# %%
import csv

# opening the csv file
with open('C:/Users/Dell/OneDrive/Desktop/accessories.csv',mode='r') as file_object:
    print("Successfully Opened csv")
    data = csv.reader(file_object)
    for line in data:
        print(line)
# Out:
# Successfully Opened csv
# ['ï»¿Name', 'Variation', 'DIY', 'Buy', 'Sell', 'Color 1', 'Color 2', 'Size', 'Miles Price', 'Source', 'Source Notes', 'Seasonal Availability', 'Mannequin Piece', 'Version', 'Style', 'Label Themes', 'Type', 'Villager Equippable', 'Catalog', 'Filename', 'Internal ID', 'Unique Entry ID']
# ['3D glasses', 'White', 'No', '490', '122', 'White', 'Colorful', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassThreed0', '4463', 'FNxEraBTeWRiCvtFu']
# ['3D glasses', 'Black', 'No', '490', '122', 'Black', 'Colorful', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassThreed1', '11020', 'mM9SXPCcGPfPJAmtm']
# ['bandage', 'Beige', 'No', '140', '35', 'Beige', 'White', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Active', 'outdoorsy; comfy; sporty', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthBandageSkin', '4677', '2qFT5iPkk8bREvpkj']
# ['beak', 'Yellow', 'No', '490', '122', 'Yellow', 'Yellow', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthBeakYellow', '3549', 'T5CpsJi4xBSachNL5']
# ['birthday shades', 'Yellow', 'No', 'NFS', '620', 'Yellow', 'Red', '1x1', 'NA', 'Birthday', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'party', 'AccessoryEye', 'Yes', 'Not for sale', 'AccessoryGlassBirthday0', '4510', 'S6CiB9ZvzBTMhEnDz']
# ['birthday shades', 'Pink', 'No', 'NFS', '620', 'Pink', 'Pink', '1x1', 'NA', 'Birthday', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'party', 'AccessoryEye', 'Yes', 'Not for sale', 'AccessoryGlassBirthday1', '11217', 'g3MPcmAKM4z5h8KYX']
# ['birthday shades', 'Red', 'No', 'NFS', '620', 'Red', 'Pink', '1x1', 'NA', 'Birthday', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'party', 'AccessoryEye', 'Yes', 'Not for sale', 'AccessoryGlassBirthday2', '11218', 'ojXoAAj8Bs2XgRiWB']
# ['birthday shades', 'Blue', 'No', 'NFS', '620', 'Light blue', 'Green', '1x1', 'NA', 'Birthday', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'party', 'AccessoryEye', 'Yes', 'Not for sale', 'AccessoryGlassBirthday3', '11219', 'Yr9mRJaZM44554oTS']
# ['bottom-rimmed glasses', 'Red', 'No', '1100', '275', 'Red', 'Red', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Simple', 'everyday; comfy; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassLoose0', '4597', 'ZHqtvcoqqDpJLf9Pc']
# ['bottom-rimmed glasses', 'Purple', 'No', '1100', '275', 'Purple', 'Purple', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Simple', 'everyday; comfy; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassLoose1', '11081', 'akRhFD3qeJEPM7WiD']
# ['bottom-rimmed glasses', 'Green', 'No', '1100', '275', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Simple', 'everyday; comfy; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassLoose2', '11082', 'EtxJZDCgnqjWkETqK']
# ['bottom-rimmed glasses', 'Blue', 'No', '1100', '275', 'Blue', 'Blue', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Simple', 'everyday; comfy; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassLoose3', '11083', 'LEbiXtkHoiEMEtjWK']
# ['bottom-rimmed glasses', 'Yellow', 'No', '1100', '275', 'Yellow', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; comfy; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassLoose4', '11084', 'w7bEbAGSQTvur6D6f']
# ['bottom-rimmed glasses', 'Pink', 'No', '1100', '275', 'Pink', 'Pink', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; comfy; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassLoose5', '11085', 'zpzD4NjApEyazKyKt']
# ['bottom-rimmed glasses', 'Black', 'No', '1100', '275', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Simple', 'everyday; comfy; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassLoose6', '11086', 'eT6KLntq43nCGFvB9']
# ['browline glasses', 'Black', 'No', '1040', '260', 'Black', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassThurmont0', '4238', 'gHxascFKEJNrLCtD9']
# ['browline glasses', 'Brown', 'No', '1040', '260', 'Brown', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassThurmont1', '11069', '9iqmzMJiAeQMBN3pk']
# ['browline glasses', 'Green', 'No', '1040', '260', 'Green', 'Gray', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassThurmont2', '11070', 'f6h8aqEufzizYBWiH']
# ['browline glasses', 'Gray', 'No', '1040', '260', 'Gray', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassThurmont3', '11071', 'R9rDoMEzPcBw75hLE']
# ['bubblegum', 'Pink', 'No', '140', '35', 'Pink', 'Pink', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthBubblegum0', '5738', '4SLmXuCkS4eBjPbLn']
# ['bubblegum', 'Blue', 'No', '140', '35', 'Light blue', 'Light blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthBubblegum1', '11027', '9wWYKTtMdo9pWqfsM']
# ['bubblegum', 'Yellow', 'No', '140', '35', 'Yellow', 'Yellow', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthBubblegum2', '11028', '79zoWzHvMBJYcwuAy']
# ['bubblegum', 'Green', 'No', '140', '35', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthBubblegum3', '11029', 'F3PoMop5MGyaxtKjZ']
# ['bubblegum', 'White', 'No', '140', '35', 'White', 'White', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthBubblegum4', '11030', 'r9N2a2TYhvXBKiihn']
# ['bunny nose', 'Pink', 'No', '560', '140', 'Pink', 'Pink', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthRabbit0', '4600', 'bxWYgcp2YKCdKe8Cr']
# ['bunny nose', 'Yellow', 'No', '560', '140', 'Yellow', 'Orange', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthRabbit1', '11023', 'y6Dp62aNQn5ixvkwf']
# ['bunny nose', 'White', 'No', '560', '140', 'White', 'Red', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthRabbit2', '11024', 'ci8RKqDmqS5wD3W5k']
# ['butterfly shades', 'Blue', 'No', '1040', '260', 'Black', 'Blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Cool', 'outdoorsy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassButterfly0', '4608', 'WjbaLp9JbBGYRrb6K']
# ['butterfly shades', 'Red', 'No', '1040', '260', 'Red', 'Brown', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Cool', 'outdoorsy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassButterfly1', '11503', 'AZrrNvHghPTHobKL4']
# ['butterfly shades', 'Brown', 'No', '1040', '260', 'Brown', 'Brown', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cool', 'outdoorsy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassButterfly2', '11504', 'rz3Pgs5XGNiQFa3t4']
# ['candy-skull mask', 'Purple', 'No', 'NFS', '800', 'White', 'Purple', '1x1', 'NA', 'Gulliver', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'formal; party; theatrical', 'AccessoryEyeMouthInvisibleNose', 'No', 'Not for sale', 'AccessoryGlassmouthCatrina0', '5666', 'GT3LzQZKg29riohcP']
# ['candy-skull mask', 'Orange', 'No', 'NFS', '800', 'White', 'Orange', '1x1', 'NA', 'Gulliver', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'formal; party; theatrical', 'AccessoryEyeMouthInvisibleNose', 'No', 'Not for sale', 'AccessoryGlassmouthCatrina1', '11169', 'xyQdqFuAkXkNs9qQ5']
# ['candy-skull mask', 'Blue', 'No', 'NFS', '800', 'White', 'Light blue', '1x1', 'NA', 'Gulliver', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'formal; party; theatrical', 'AccessoryEyeMouthInvisibleNose', 'No', 'Not for sale', 'AccessoryGlassmouthCatrina2', '11170', 'fev4af8sNdggceyW9']
# ['cat nose', 'White', 'No', '560', '140', 'White', 'Pink', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthCat0', '4483', '45Muns9ig4dqrsFF7']
# ['cat nose', 'Brown', 'No', '560', '140', 'Brown', 'Beige', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthCat1', '11021', 'CXDCEFzBdv8DwkCyM']
# ['cat nose', 'Navy blue', 'No', '560', '140', 'Blue', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthCat2', '11022', 'ywdWXRcwKJNMMxDyj']
# ['cucumber pack', 'Green', 'No', '490', '122', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthCucumber', '4491', 'MhbCBrYX5fHxZWDuA']
# ['curly mustache', 'Black', 'No', '700', '175', 'Colorful', 'Colorful', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Simple', 'fairy tale; formal; party', 'AccessoryMouthEarJaw', 'No', 'For sale', 'AccessoryMouthRollingmustacheBlack', '4672', '9tyCrNPeibcu5NLo8']
# ['cyber shades', 'Red', 'No', '1300', '325', 'Red', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassCyber0', '4552', '3YPuxxPLkzwwNQMQd']
# ['cyber shades', 'Black', 'No', '1300', '325', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassCyber1', '11498', '67BAc4y8aADafp9Xk']
# ['cyber shades', 'Silver', 'No', '1300', '325', 'Gray', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassCyber2', '11499', 'AKakpCweRnd5hAsRB']
# ['cyber shades', 'Purple', 'No', '1300', '325', 'Purple', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassCyber3', '11500', 'y2svNHScnr8cNZe86']
# ['cyber shades', 'Green', 'No', '1300', '325', 'Green', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassCyber4', '11501', '9izTCDGHSpqWrQp6T']
# ['cyber shades', 'Yellow', 'No', '1300', '325', 'Yellow', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassCyber5', '11502', '5pk9ZMDGsEzLqp24L']
# ['DAL eye mask', 'Blue', 'No', 'NFS', '1010', 'Blue', 'Blue', '1x1', 'NA', 'Dodo Airlines', 'Received in mail from DAL after taking certain numbers of flights', 'All Year', 'No', '1.0.0', 'Simple', 'comfy; vacation', 'AccessoryEye', 'Yes', 'Not for sale', 'AccessoryGlassDalmask0', '12128', 'sbkqQrHpJWMEEZLSR']
# ['DAL sunglasses', 'Yellow', 'No', 'NFS', '1010', 'Yellow', 'Blue', '1x1', 'NA', 'Dodo Airlines', 'Received in mail from DAL after taking certain numbers of flights', 'All Year', 'No', '1.0.0', 'Gorgeous', 'comfy; vacation', 'AccessoryEye', 'Yes', 'Not for sale', 'AccessoryGlassDalglass0', '12129', 'zRnkH9B3rYNMLpiTP']
# ["doctor's mask", 'White', 'No', '140', '35', 'White', 'White', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'everyday; goth; comfy', 'AccessoryMouthEarJaw', 'No', 'For sale', 'AccessoryMouthMaskWhite', '4451', 'vZDsrDRdgrbbiwi8N']
# ['dog nose', 'White', 'No', '560', '140', 'White', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthDog0', '5244', 'moGRcnkQihHbN89Kc']
# ['dog nose', 'Beige', 'No', '560', '140', 'Orange', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthDog1', '11025', 'zCQqXy8HLE7rDfrQf']
# ['dog nose', 'Black', 'No', '560', '140', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthDog2', '11026', '9JGbmWtDA3rmjf8Kc']
# ['double-bridge glasses', 'Gold', 'No', '1100', '275', 'Yellow', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Elegant', 'comfy; vacation; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassDoublebridge0', '4263', '8QCnzjXY8KEyqf7Wa']
# ['double-bridge glasses', 'Purple', 'No', '1100', '275', 'Purple', 'Purple', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Elegant', 'comfy; vacation; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassDoublebridge1', '11076', 'guPGRuhMyqdWYKh8d']
# ['double-bridge glasses', 'Silver', 'No', '1100', '275', 'Gray', 'Gray', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Elegant', 'comfy; vacation; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassDoublebridge2', '11077', 'CLPEzZqr3vut85Ja4']
# ['double-bridge glasses', 'Blue', 'No', '1100', '275', 'Blue', 'Blue', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Elegant', 'comfy; vacation; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassDoublebridge3', '11078', 'fD5pteAQtC8CMhq2v']
# ['drinking-straw glasses', 'Green', 'No', '560', '140', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Active', 'comfy; vacation; work', 'AcceEyeMouth', 'No', 'For sale', 'AccessoryGlassmouthStraw0', '5773', 'hMiEGoaE2jYb6kY4e']
# ['drinking-straw glasses', 'Blue', 'No', '560', '140', 'Light blue', 'Light blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Active', 'comfy; vacation; work', 'AcceEyeMouth', 'No', 'For sale', 'AccessoryGlassmouthStraw1', '11010', 'DNij9RhiMW39MtKWF']
# ['drinking-straw glasses', 'Pink', 'No', '560', '140', 'Pink', 'Pink', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Active', 'comfy; vacation; work', 'AcceEyeMouth', 'No', 'For sale', 'AccessoryGlassmouthStraw2', '11011', 'b4G7SFYMTs5YWJ4i5']
# ['drinking-straw glasses', 'White', 'No', '560', '140', 'White', 'White', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Active', 'comfy; vacation; work', 'AcceEyeMouth', 'No', 'For sale', 'AccessoryGlassmouthStraw3', '11012', 'bQ67Xe7cQZ4PcXnNe']
# ['eye mask', 'Blue', 'No', '560', '140', 'Blue', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMask0', '4425', '68oXMszxbRtGoe9tH']
# ['eye mask', 'Pink', 'No', '560', '140', 'Pink', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMask1', '11154', 'Ck7jeovxpJEQa9BXB']
# ['eye mask', 'Gray', 'No', '560', '140', 'Gray', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMask2', '11155', 'FFAmL82w7xmtQyj49']
# ['eye mask', 'Green', 'No', '560', '140', 'Green', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMask3', '11156', 'csWKsYtw2k9ADBQpT']
# ['eye mask', 'Orange', 'No', '560', '140', 'Orange', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMask4', '11157', 'Gy2FEnpkD9KrRshtd']
# ['eye mask', 'Red', 'No', '560', '140', 'Red', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMask5', '11158', 'DN9e9e3kPAvftJL7X']
# ['eye patch', 'Black', 'No', '140', '35', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'fairy tale; goth', 'AccessoryOneEye', 'Yes', 'For sale', 'AccessoryGlassPatchBlack', '4457', 'iZoTNGb8htGE8JWEw']
# ['facial mask', 'White', 'No', '560', '140', 'White', 'White', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Simple', 'goth; comfy', 'AcceEyeMouth', 'No', 'For sale', 'AccessoryGlassmouthPackWhite', '4512', 'KzBY9kLtwTHhHGzR3']
# ['fake nose', 'Red', 'No', '490', '122', 'Red', 'Red', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AcceEyeMouth', 'No', 'For sale', 'AccessoryGlassmouthNoseRed', '4496', 'chP2wAyDtdSTS3XrF']
# ['flower sunglasses', 'Red', 'No', '770', '192', 'Red', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassFlower0', '5739', 'iJsQqLTdb4gcPwekJ']
# ['flower sunglasses', 'Orange', 'No', '770', '192', 'Orange', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassFlower1', '11228', '6TygyrRpgFEJRtYAD']
# ['flower sunglasses', 'Blue', 'No', '770', '192', 'Blue', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassFlower2', '11229', 'g4jdQJuTAwEgGWsyH']
# ['flower sunglasses', 'Purple', 'No', '770', '192', 'Purple', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassFlower3', '11230', 'hN8mRmSqAqfBBXqsK']
# ['flower sunglasses', 'Green', 'No', '770', '192', 'Green', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassFlower4', '11231', 'vnNLfafLRpv9vrESq']
# ['food mess', 'Pasta', 'No', '490', '122', 'Orange', 'Beige', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthPasta', '5857', 'ErTpS7LHoG7hZ4bvn']
# ['funny glasses', 'Brown', 'No', '1100', '275', 'Brown', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassEyes0', '4513', 'nvgwq4bKZzDoiTQzw']
# ['funny glasses', 'Pink', 'No', '1100', '275', 'Pink', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassEyes1', '11008', '4ASpkj55QiocnNkZ2']
# ['funny glasses', 'Blue', 'No', '1100', '275', 'Light blue', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassEyes2', '11009', 'dio9gmQCebNSjSX89']
# ['gas mask', 'Black', 'No', '1100', '275', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'goth; work', 'AcceEyeMouth', 'No', 'For sale', 'AccessoryGlassmouthGasmask0', '4649', 'cuqWQPfsbkmXz5DuB']
# ['gas mask', 'Avocado', 'No', '1100', '275', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'goth; work', 'AcceEyeMouth', 'No', 'For sale', 'AccessoryGlassmouthGasmask1', '11160', '9K9ea2sRHMsPmcX6d']
# ['glass-bottle glasses', 'Black', 'No', '1100', '275', 'Black', 'Gray', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBottleBlack', '4282', 'JFtffcGH7WnPnJKtc']
# ['goatee', 'Black', 'No', '980', '245', 'Colorful', 'Colorful', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cool', 'everyday; comfy; theatrical', 'AccessoryMouthEarJaw', 'No', 'For sale', 'AccessoryMouthBeardChinBlack', '4676', 'W5S7BC9qA4QMCQEFR']
# ['goggles', 'Black', 'No', '560', '140', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'Summer', 'No', '1.0.0', 'Active', 'outdoorsy; sporty; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGoggles0', '4454', '3YkDq5TZm3jE8nBL9']
# ['goggles', 'Blue', 'No', '560', '140', 'Blue', 'Blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'Summer', 'No', '1.0.0', 'Active', 'outdoorsy; sporty; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGoggles1', '11484', 'gozwdhewwK4PmPGFQ']
# ['goggles', 'Pink', 'No', '560', '140', 'Pink', 'Pink', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'Summer', 'No', '1.0.0', 'Active', 'outdoorsy; sporty; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGoggles2', '11485', '49s9b7jcrE8uaFEdR']
# ['goggles', 'Green', 'No', '560', '140', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'Summer', 'No', '1.0.0', 'Active', 'outdoorsy; sporty; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGoggles3', '11486', 'sDjZobRoupcETEKeH']
# ['goggles', 'Purple', 'No', '560', '140', 'Purple', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'Summer', 'No', '1.0.0', 'Active', 'outdoorsy; sporty; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGoggles4', '11487', 'kwS6ErrZHdDNXpmbR']
# ['goggles', 'Red', 'No', '560', '140', 'Red', 'Red', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'Summer', 'No', '1.0.0', 'Active', 'outdoorsy; sporty; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGoggles5', '11488', 'P8X4Rnuc6WjHTrbkz']
# ['handlebar mustache', 'Black', 'No', '1120', '280', 'Colorful', 'Colorful', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Elegant', 'fairy tale; formal; theatrical', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthBeardBlack', '3550', 'HJfvmuhPDFMN8eRB2']
# ['heart shades', 'Pink', 'No', '1040', '260', 'Pink', 'Blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassHeart0', '4237', 'ZkwfoAxXwqiJav677']
# ['heart shades', 'Yellow', 'No', '1040', '260', 'Yellow', 'Blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassHeart1', '11188', 'jvPC7gmEHvxxgmwfA']
# ['heart shades', 'Blue', 'No', '1040', '260', 'Light blue', 'Blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassHeart2', '11189', 'k2fF9yEC5S3XGsXhX']
# ['heart shades', 'Purple', 'No', '1040', '260', 'Purple', 'Blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassHeart3', '11190', '3fs7r8mBn9EiGmMT7']
# ['heart shades', 'Green', 'No', '1040', '260', 'Green', 'Blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassHeart4', '11191', 'CbiyKw9gGsMfYzA4g']
# ['HMD', 'White', 'No', '2000', '500', 'White', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'comfy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassHmdWhite', '5182', 'Hkcb2b5RCvgcXrHvc']
# ["jester's mask", 'Black', 'No', '1760', '440', 'Black', 'White', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'fairy tale; goth; party; theatrical; work', 'AccessoryEyeMouthInvisibleNose', 'No', 'For sale', 'AccessoryGlassmouthPierrot0', '4678', '5iGdajwpPAQ98B9eE']
# ["jester's mask", 'Red', 'No', '1760', '440', 'Red', 'White', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'fairy tale; goth; party; theatrical; work', 'AccessoryEyeMouthInvisibleNose', 'No', 'For sale', 'AccessoryGlassmouthPierrot1', '11166', '7HBtvdHttSMJiuA7W']
# ["jester's mask", 'Green', 'No', '1760', '440', 'Green', 'White', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'fairy tale; goth; party; theatrical; work', 'AccessoryEyeMouthInvisibleNose', 'No', 'For sale', 'AccessoryGlassmouthPierrot2', '11167', 'LTCnc3SoDzsffayDr']
# ["jester's mask", 'Blue', 'No', '1760', '440', 'Blue', 'White', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'fairy tale; goth; party; theatrical; work', 'AccessoryEyeMouthInvisibleNose', 'No', 'For sale', 'AccessoryGlassmouthPierrot3', '11168', 'Kpyk7xszcwxgdawqA']
# ['Labelle sunglasses', 'Twilight', 'No', '2000', '500', 'Purple', 'Purple', '1x1', 'NA', 'Labelle', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'everyday; formal; party; theatrical; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassKate0', '9887', '2B4ttG2NJS7ZKRimP']
# ['Labelle sunglasses', 'Midnight', 'No', '2000', '500', 'Black', 'Black', '1x1', 'NA', 'Labelle', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'everyday; formal; party; theatrical; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassKate1', '11776', 'Pk4syNKBscFTBD2mP']
# ['Labelle sunglasses', 'Passion', 'No', '2000', '500', 'Red', 'Red', '1x1', 'NA', 'Labelle', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'everyday; formal; party; theatrical; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassKate2', '11777', 'TJqYcpQKFaPX6naSj']
# ['Labelle sunglasses', 'Ocean', 'No', '2000', '500', 'Blue', 'Blue', '1x1', 'NA', 'Labelle', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'everyday; formal; party; theatrical; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassKate3', '11778', 'yWuQ9CtGKLaG7ntW9']
# ['Labelle sunglasses', 'Sunset', 'No', '2000', '500', 'Yellow', 'Yellow', '1x1', 'NA', 'Labelle', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'everyday; formal; party; theatrical; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassKate4', '11779', 'Km6htuKWbDhQx5v2o']
# ['Labelle sunglasses', 'Love', 'No', '2000', '500', 'Pink', 'Pink', '1x1', 'NA', 'Labelle', '', 'All Year', 'No', '1.0.0', 'Gorgeous', 'everyday; formal; party; theatrical; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassKate5', '11780', 'WHaB5ZbzSPteM5KxG']
# ['ladder shades', 'Red', 'No', '880', '220', 'Red', 'Red', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBlind0', '4464', 'DErjYKaqmFEkp7RQ3']
# ['ladder shades', 'Blue', 'No', '880', '220', 'Blue', 'Blue', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBlind1', '11002', 'kbZR8T9YaP2Pb7q6P']
# ['ladder shades', 'Green', 'No', '880', '220', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBlind2', '11003', 'wnvu2B7z7M975uCMf']
# ['ladder shades', 'Pink', 'No', '880', '220', 'Pink', 'Pink', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBlind3', '11004', '8wvE7HfG9HvK33nTW']
# ['ladder shades', 'Yellow', 'No', '880', '220', 'Yellow', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBlind4', '11005', 'mcex6oPn8f8KotnrZ']
# ['ladder shades', 'Gold', 'No', '880', '220', 'Brown', 'Brown', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBlind5', '11006', 'SF89YKrjwGsa5Dp7t']
# ['leaf', 'Green', 'Yes', 'NFS', '100', 'Green', 'Green', '1x1', 'NA', 'Crafting', '', 'All Year', 'No', '1.0.0', 'Simple', 'outdoorsy; comfy; vacation', 'AccessoryMouth', 'No', 'Not for sale', 'AccessoryMouthLeafGreen', '4682', 'XrpTjwp94FwmvXjmE']
# ['masquerade mask', 'Purple', 'No', '910', '227', 'Pink', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'fairy tale; party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassVenetian0', '4667', 'vwytnsJLdnFYZdeHR']
# ['masquerade mask', 'Black', 'No', '910', '227', 'Black', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'fairy tale; party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassVenetian1', '11161', 'GL9igRSB2nTebNAin']
# ['masquerade mask', 'Blue', 'No', '910', '227', 'Blue', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'fairy tale; party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassVenetian2', '11162', '6yKLSWNnpyXAPKJ4h']
# ['masquerade mask', 'Red', 'No', '910', '227', 'Red', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'fairy tale; party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassVenetian3', '11163', 'DknNtTo9sb2jZHDht']
# ['masquerade mask', 'Green', 'No', '910', '227', 'Green', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'fairy tale; party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassVenetian4', '11164', 'PEA7Y7djsLQryh4c2']
# ['masquerade mask', 'Gold', 'No', '910', '227', 'Orange', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'fairy tale; party; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassVenetian5', '11165', 'nzAimcCqJg46jjNiN']
# ['monocle', 'Black', 'No', '1100', '275', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Elegant', 'fairy tale; formal; work', 'AccessoryOneEye', 'Yes', 'For sale', 'AccessoryGlassMonocle0', '4462', 'vtCepd9DjYS2H5vcb']
# ['monocle', 'Gold', 'No', '1100', '275', 'Yellow', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Elegant', 'fairy tale; formal; work', 'AccessoryOneEye', 'Yes', 'For sale', 'AccessoryGlassMonocle1', '11000', 'ghxLRorCD3NWR5h5x']
# ['monocle', 'Silver', 'No', '1100', '275', 'Gray', 'Gray', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Elegant', 'fairy tale; formal; work', 'AccessoryOneEye', 'Yes', 'For sale', 'AccessoryGlassMonocle2', '11001', 'tXaLxYbQPqcTZWxej']
# ['night-vision goggles', 'Black', 'No', '1560', '390', 'Black', 'Green', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Active', 'outdoorsy', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassNightvisionBlack', '5261', 'sMdtidR3zypRsgSCW']
# ['Nook Inc. eye mask', 'Green', 'No', 'NFS', '2000', 'Green', 'White', '1x1', '400', 'Nook Miles Shop', '', 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryEye', 'Yes', 'Not for sale', 'AccessoryGlassNook0', '9654', 'n8j5gx4zjuK7tkYKq']
# ['nose drip', 'Light blue', 'No', '490', '122', 'Light blue', 'Light blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthJokeDripCyan', '5833', '9YbFJqBD3hmQkW4Gq']
# ['octagonal glasses', 'Gray', 'No', '1100', '275', 'Gray', 'Gray', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cute', 'comfy; vacation; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOctagon0', '4239', 'dzKG7sMGwFn7EaKjm']
# ['octagonal glasses', 'Green', 'No', '1100', '275', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'comfy; vacation; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOctagon1', '11072', 'NME2CQfz2tMbnwLzb']
# ['octagonal glasses', 'Purple', 'No', '1100', '275', 'Purple', 'Purple', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cute', 'comfy; vacation; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOctagon2', '11073', 'Je9RNoLocnJ5kinNQ']
# ['octagonal glasses', 'Gold', 'No', '1100', '275', 'Beige', 'Beige', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cute', 'comfy; vacation; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOctagon3', '11074', 't5MJmR6fbqXwevjus']
# ['octagonal glasses', 'Black', 'No', '1100', '275', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cute', 'comfy; vacation; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOctagon4', '11075', '4FT4YuTQcq3RGo3Ss']
# ['oval glasses', 'Green', 'No', '880', '220', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOval0', '4609', 'jw7KgW9epPat5Pw8W']
# ['oval glasses', 'Orange', 'No', '880', '220', 'Orange', 'Orange', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOval1', '11087', '9AXkAraeTz6TgR6sJ']
# ['oval glasses', 'Blue', 'No', '880', '220', 'Light blue', 'Light blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'everyday; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOval2', '11088', 'ydCsvEetGaAQ4mNs2']
# ['oval glasses', 'Purple', 'No', '880', '220', 'Purple', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'everyday; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOval3', '11089', '9ZhHgTmKeqZ7fgcNr']
# ['oval glasses', 'Magenta', 'No', '880', '220', 'Red', 'Red', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOval4', '11090', 'QBNkZLi9jpeDYMxnQ']
# ['oval glasses', 'Mustard', 'No', '880', '220', 'Yellow', 'Yellow', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'everyday; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOval5', '11091', 'uocqzyhP5WHmnH8dj']
# ['oval glasses', 'Black', 'No', '880', '220', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'everyday; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassOval6', '11092', 'uuttmaKAruqm7tiKL']
# ['pacifier', 'Baby purple', 'No', '560', '140', 'Pink', 'Pink', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthPacifier0', '2298', 'bK8fXPaAy9f3Nqx9Q']
# ['pacifier', 'Baby mint', 'No', '560', '140', 'Light blue', 'Light blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthPacifier1', '11013', 'KMB2YJMHNzESo6Hws']
# ['pacifier', 'Baby yellow', 'No', '560', '140', 'Yellow', 'Yellow', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthPacifier2', '11014', 'iH9JsLkZTan5CQgTt']
# ['pacifier', 'Baby green', 'No', '560', '140', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthPacifier3', '11015', 'XRyQwLEtt9RwgvtST']
# ['pacifier', 'Baby pink', 'No', '560', '140', 'Red', 'Red', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthPacifier4', '11016', 'iAyukzDt8Kutfpmab']
# ['pacifier', 'Baby gray', 'No', '560', '140', 'Gray', 'Gray', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthPacifier5', '11017', 'aWcYia7rWZ8nhXg37']
# ['pacifier', 'Baby blue', 'No', '560', '140', 'Purple', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthPacifier6', '11018', 'ScuP52AjZHPkhCuGP']
# ['pacifier', 'Baby orange', 'No', '560', '140', 'Orange', 'Orange', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthPacifier7', '11019', 'WZgrieHNMrjuw9Tah']
# ['pig nose', 'Pink', 'No', '560', '140', 'Pink', 'Pink', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'fairy tale; party; theatrical', 'AccessoryMouthInvisibleNose', 'No', 'For sale', 'AccessoryMouthPigPink', '4647', 'H2JSW7YDoTdLr6GTK']
# ['pilot shades', 'Black', 'No', '1300', '325', 'Black', 'Brown', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cool', 'sporty; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassPilot0', '4459', 'wuyb75e6fkA5976yx']
# ['pilot shades', 'Gold', 'No', '1300', '325', 'Yellow', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Cool', 'sporty; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassPilot1', '11214', 'nBHTPo8pt7eRL47PT']
# ['pixel shades', 'Red', 'No', '1320', '330', 'Red', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cool', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassDot0', '4646', 'Tp2dC3Dk4chwa4ebr']
# ['pixel shades', 'Green', 'No', '1320', '330', 'Green', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassDot1', '11223', '6tFnu3DhC5HQvqmZ5']
# ['pixel shades', 'Blue', 'No', '1320', '330', 'Blue', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cool', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassDot2', '11224', 'SbAGGe9yg4EXAw35b']
# ['pixel shades', 'Black', 'No', '1320', '330', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassDot3', '11225', 'GY4PDqrCZdcPWb4Ep']
# ['pleather mask', 'Black', 'No', '770', '192', 'Black', 'Gray', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cool', 'goth', 'AccessoryMouthEarJaw', 'No', 'For sale', 'AccessoryMouthLeatherBlack', '6040', 'aN6Wsxguggh39oBiF']
# ['post-op patch', 'White', 'No', '490', '122', 'White', 'White', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'goth', 'AccessoryOneEye', 'Yes', 'For sale', 'AccessoryGlassEyepatchWhite', '4452', '8Qgoizxz547DtMNd7']
# ['privacy mask', 'Black', 'No', '560', '140', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cool', 'everyday; goth; comfy', 'AccessoryMouthEarJaw', 'No', 'For sale', 'AccessoryMouthCrowBlack', '4671', '4GDJFfMNHhsaXXrAN']
# ['reflector', 'Gray', 'No', '560', '140', 'Gray', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMirrorGray', '6039', 'J4EgETRkyeSESkRB7']
# ['retro shades', 'Yellow', 'No', '1560', '390', 'White', 'Orange', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Elegant', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRetro0', '4456', 'SFFhXhR5sYQzJwXWj']
# ['retro shades', 'Green', 'No', '1560', '390', 'Green', 'Green', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Elegant', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRetro1', '11209', 'zYw3PhLHsw2KZ7TBK']
# ['retro shades', 'Red', 'No', '1560', '390', 'Pink', 'Red', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Elegant', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRetro2', '11210', 'zg6uY6WZNQcopNq67']
# ['retro shades', 'Purple', 'No', '1560', '390', 'Pink', 'Purple', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Elegant', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRetro3', '11211', 'QqEG7ktLKMaXweFzg']
# ['retro shades', 'Blue', 'No', '1560', '390', 'Light blue', 'Green', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Elegant', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRetro4', '11212', 'cJCaAmMdqrHG8uDLH']
# ['retro shades', 'Gray', 'No', '1560', '390', 'Gray', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Elegant', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRetro5', '11213', '6oqHAyihAjKRfH72Z']
# ['rhinestone shades', 'Red', 'No', '1040', '260', 'Red', 'Red', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'party; theatrical; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRhinestone0', '4683', 'BJFhJqt9KuaWGaWuM']
# ['rhinestone shades', 'Ochre', 'No', '1040', '260', 'Brown', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'party; theatrical; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRhinestone1', '11226', 'iwtSmya59DpyGFB97']
# ...
# ['round shades', 'Yellow', 'No', '1560', '390', 'Yellow', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBoston3', '11198', 'BE37D4h9xHkhRwgmH']
# ['round shades', 'Pink', 'No', '1560', '390', 'Pink', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBoston4', '11199', 'KFNjnL6rqYckLECFB']
# ['round shades', 'Red', 'No', '1560', '390', 'Red', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'Yes', '1.0.0', 'Cool', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBoston5', '11200', 'Z9bJ6cYkY6hC4mL4o']
# ['round shades', 'White', 'No', '1560', '390', 'White', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBoston6', '11201', 'z8KywWDutyXSsgXoy']
# ['round shades', 'Purple', 'No', '1560', '390', 'Purple', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'everyday; party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassBoston7', '11202', 'fy6sue9jdYtpwh4Aq']
# ['round tinted shades', 'Brown', 'No', '880', '220', 'Orange', 'Brown', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRound0', '4607', 'GdrT6sBLFECRG8LyN']
# ['round tinted shades', 'Light brown', 'No', '880', '220', 'Orange', 'Brown', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRound1', '11220', 'KqtiBXYfKejymQ4Wg']
# ['round tinted shades', 'Dark brown', 'No', '880', '220', 'Brown', 'Brown', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRound2', '11221', 'tfuBgNyNNSXc3o4Q2']
# ['round tinted shades', 'Green', 'No', '880', '220', 'Green', 'Brown', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassRound3', '11222', 'CeX6fKZRL2XFK7jnW']
# ['rounded beard', 'Black', 'No', '980', '245', 'Colorful', 'Colorful', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'everyday; comfy; theatrical', 'AccessoryMouthEarJaw', 'No', 'For sale', 'AccessoryMouthBeardRoundBlack', '4679', 'As4RR5kDBbDWqHP69']
# ['shattered glasses', 'Black', 'No', 'NFS', '10', 'Black', 'Light blue', '1x1', 'NA', 'Recycle bin', '', 'All Year', 'No', '1.0.0', 'Simple', 'goth', 'AccessoryEye', 'Yes', 'Not for sale', 'AccessoryGlassCrackBlack', '4337', '9nxh9LSDKZoYjygJg']
# ['ski goggles', 'White', 'No', '980', '245', 'Orange', 'White', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'Winter', 'Yes', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGogglesski0', '4453', 'GWhWLPt3sExfeAG2c']
# ['ski goggles', 'Yellow', 'No', '980', '245', 'Pink', 'Yellow', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'Winter', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGogglesski1', '11479', 'NwNqq5g2iw4DeMsBY']
# ['ski goggles', 'Purple', 'No', '980', '245', 'Green', 'Blue', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'Winter', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGogglesski2', '11480', '4umKSoR2BWtW6JyFK']
# ['ski goggles', 'Pink', 'No', '980', '245', 'Purple', 'Pink', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'Winter', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGogglesski3', '11481', 'RBByDZoTeK5b6jvXn']
# ['ski goggles', 'Green', 'No', '980', '245', 'Blue', 'Green', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'Winter', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGogglesski4', '11482', 'SydPBHGEnpRAKuCfq']
# ['ski goggles', 'Orange', 'No', '980', '245', 'Light blue', 'Orange', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'Winter', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassGogglesski5', '11483', 'vSksuA8nCN72Tq3ji']
# ['sporty shades', 'Black', 'No', '1300', '325', 'Black', 'Orange', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSports0', '4458', 'QkHqffg8X4eTL6PXX']
# ['sporty shades', 'White', 'No', '1300', '325', 'White', 'Orange', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSports1', '11489', 'CA5YASgCBpgL2PSpX']
# ['sporty shades', 'Pink', 'No', '1300', '325', 'Pink', 'Pink', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSports2', '11490', 'GgdcckY8p5Rg5NyTY']
# ['sporty shades', 'Lime', 'No', '1300', '325', 'Green', 'Light blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSports3', '11491', 'uwEjreWEdYSbuxXE9']
# ['sporty shades', 'Light blue', 'No', '1300', '325', 'Light blue', 'Blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Active', 'outdoorsy; sporty', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSports4', '11492', 'THB8TWPykhsELXErr']
# ['square glasses', 'Brown', 'No', '880', '220', 'Brown', 'Brown', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSquare0', '4236', 'rAzkKijSEqXzoAZKY']
# ['square glasses', 'Black', 'No', '880', '220', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSquare1', '11066', 'LhvFWS5ADiDiPJwai']
# ['square glasses', 'Gray', 'No', '880', '220', 'Gray', 'Gray', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'everyday; formal; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSquare2', '11067', 'QxFwFytYcWo5acGtW']
# ['square glasses', 'Blue', 'No', '880', '220', 'Blue', 'Blue', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSquare3', '11068', 'CvziuqadDpoQgGK4C']
# ['stache & glasses', 'Black', 'No', '770', '192', 'Black', 'Orange', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'party; theatrical', 'AcceEyeMouth', 'Yes', 'For sale', 'AccessoryGlassmouthBeard0', '4501', 's7hDzZ3ajPpK9fnEW']
# ['stache & glasses', 'Red', 'No', '770', '192', 'Red', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cute', 'party; theatrical', 'AcceEyeMouth', 'Yes', 'For sale', 'AccessoryGlassmouthBeard1', '11007', 'M8owND8DnAEKA9nuX']
# ['star shades', 'Yellow', 'No', '880', '220', 'Yellow', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassStar0', '4240', 'y4n8SisxyS7dGRWL7']
# ['star shades', 'Pink', 'No', '880', '220', 'Pink', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassStar1', '11192', 'PCZAYraP9kdaqnZy7']
# ['star shades', 'Blue', 'No', '880', '220', 'Light blue', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassStar2', '11193', 'h4zk6rrWiX94jefGH']
# ['star shades', 'Purple', 'No', '880', '220', 'Purple', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassStar3', '11194', 'GiBvxa93RwTN46zhE']
# ['star shades', 'Green', 'No', '880', '220', 'Green', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassStar4', '11195', 'PaF6nho2LRBu5x7Pi']
# ['steampunk glasses', 'Green', 'No', '1300', '325', 'Brown', 'Green', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'fairy tale; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSteampunk0', '4685', 'uANDLz5EDWphoM3Lc']
# ['steampunk glasses', 'Purple', 'No', '1300', '325', 'Brown', 'Purple', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Gorgeous', 'fairy tale; theatrical', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassSteampunk1', '11505', 'Rhhrv89PGEMbdbdPt']
# ['sticky rice', 'White', 'No', '490', '122', 'White', 'White', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'comfy', 'AccessoryMouth', 'No', 'For sale', 'AccessoryMouthRice', '4652', 'isnXDFfGkHKKB8bMP']
# ['superhero mask', 'Black', 'No', '1040', '260', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', 'Available from Able Sisters shop only', 'All Year', 'No', '1.0.0', 'Cool', 'fairy tale; theatrical; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassHeromaskBlack', '4684', 'fK2Xz8nxAebSkWNdE']
# ['tiny shades', 'Gold', 'No', '1100', '275', 'Yellow', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Cool', 'fairy tale; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMini0', '4461', 'DnZtrKfwj3MAy6PZc']
# ['tiny shades', 'Black', 'No', '1100', '275', 'Black', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cool', 'fairy tale; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMini1', '11215', 'tCxZoqcR8egLcu4oh']
# ['tiny shades', 'Berry red', 'No', '1100', '275', 'Red', 'Black', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cool', 'fairy tale; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassMini2', '11216', '8YkgkHp2z5tycST3j']
# ['tortoise specs', 'Brown', 'No', '1040', '260', 'Brown', 'Orange', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTortoiseshell0', '4460', 'kqomsYL33TB7zaNtY']
# ['tortoise specs', 'Beige', 'No', '1040', '260', 'Orange', 'Beige', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTortoiseshell1', '11079', 'jewJFqgFQTHKyAKTz']
# ['tortoise specs', 'Black', 'No', '1040', '260', 'Black', 'Beige', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTortoiseshell2', '11080', 'fEshNAFDwcyo9v2fX']
# ['triangle shades', 'Red', 'No', '880', '220', 'Red', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTriangle0', '4242', 'cw8m5tS85qMGGnpy9']
# ['triangle shades', 'Orange', 'No', '880', '220', 'Orange', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTriangle1', '11203', 'cR58LxuFK4Kcxh7fc']
# ['triangle shades', 'Blue', 'No', '880', '220', 'Light blue', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTriangle2', '11204', 'xSM4vD2KSok5cjo6p']
# ['triangle shades', 'Purple', 'No', '880', '220', 'Purple', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTriangle3', '11205', 'vAuSuBJcAfyMR6wk7']
# ['triangle shades', 'Green', 'No', '880', '220', 'Green', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTriangle4', '11206', '4edkdodmNhmpkSCBo']
# ['triangle shades', 'White', 'No', '880', '220', 'White', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTriangle5', '11207', 'QpAQQTRoBmcjNBeEK']
# ['triangle shades', 'Black', 'No', '880', '220', 'Black', 'Purple', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'No', '1.0.0', 'Cute', 'party; vacation', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassTriangle6', '11208', 'vGHab8KFNDFRgW5h6']
# ['wooden-frame glasses', 'Brown', 'No', '1560', '390', 'Brown', 'Gray', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassWood0', '4669', 'dbnqry4vZBvK6LrS2']
# ['wooden-frame glasses', 'Dark brown', 'No', '1560', '390', 'Brown', 'Yellow', '1x1', 'NA', 'Able Sisters', "Available from either Mable's temporary shop or Able Sisters shop", 'All Year', 'Yes', '1.0.0', 'Simple', 'everyday; formal; work', 'AccessoryEye', 'Yes', 'For sale', 'AccessoryGlassWood1', '11093', '2MufTC9TPErbryyKS']

# %%
import csv
filename = 'C:/Users/Dell/OneDrive/Desktop/Student Mental health.csv'
fields = []
rows = []
with open(filename,mode='r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
    for coloumname in fields:
        print(coloumname)
# Out:
# Timestamp
# Choose your gender
# Age
# What is your course?
# Your current year of Study
# What is your CGPA?
# Marital status
# Do you have Depression?
# Do you have Anxiety?
# Do you have Panic attack?
# Did you seek any specialist for a treatment?

# %%
import csv
c=0
# opening the csv file
with open('C:/Users/Dell/OneDrive/Desktop/summer.csv',mode='r') as fd:
    #print("Successfully Opened csv")
    data = csv.reader(fd)
    print(type(data))
    for line in data:
        c = c+1
        if c>5:
            break
        if c==1:
            continue
        print(c,"Participated in",line[3],'got',line[8] ,'medal',c)
# Out:
# <class '_csv.reader'>
# 2 Participated in Swimming got Gold medal 2
# 3 Participated in Swimming got Silver medal 3
# 4 Participated in Swimming got Bronze medal 4
# 5 Participated in Swimming got Gold medal 5

# %%
import csv
filename = 'C:/Users/Dell/OneDrive/Desktop/posters.csv'
fields = []
rows = []
with open(filename,mode='r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
   # for coloumname in fields:
   #     print(coloumname)
    for row in csvreader:
       # print((type(row)))
        rows.append(row)
       # print(rows)
for row in rows[:5]:
    for col in row:
        print("%10s"%col,end="")
    print("\n")
# Out:
# Admiral's poster      1000       250     Green      Blue       1x1Nook's Shopping - PostersIn the Special Items section in Nook Shopping, after inviting the villager to Photopia (either through amiibo, or if the villager lives in your town)     1.0.0  For salePosterNpcNmlBrd06     108143LW8HyqLZTJRaGQT9
#
# Agent S's poster      1000       250      Blue      Gray       1x1Nook's Shopping - PostersIn the Special Items section in Nook Shopping, after inviting the villager to Photopia (either through amiibo, or if the villager lives in your town)     1.0.0  For salePosterNpcNmlSqu05     10425bZu92nbNfGmQvp54D
#
# Agnes's poster      1000       250      Pink     Black       1x1Nook's Shopping - PostersIn the Special Items section in Nook Shopping, after inviting the villager to Photopia (either through amiibo, or if the villager lives in your town)     1.0.0  For salePosterNpcNmlPig17     104012wZBfe8Ed7QMvQ8tX
#
# Al's poster      1000       250       RedLight blue       1x1Nook's Shopping - PostersIn the Special Items section in Nook Shopping, after inviting the villager to Photopia (either through amiibo, or if the villager lives in your town)     1.0.0  For salePosterNpcNmlGor08     10590sat2PG8L97DymZbQw
#
# Alfonso's poster      1000       250    Orange       Red       1x1Nook's Shopping - PostersIn the Special Items section in Nook Shopping, after inviting the villager to Photopia (either through amiibo, or if the villager lives in your town)     1.0.0  For salePosterNpcNmlCrd00     10382NjW35Zc7MnTipYZbg

# %%
import csv
filename = 'C:/Users/Dell/OneDrive/Desktop/covid_19.csv'
fields = []
rows = []
with open(filename,mode='r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
    for coloumname in fields:
        print(coloumname)
# Out:
# Province/State
# Country/Region
# Lat
# Long
# Date
# Confirmed
# Deaths
# Recovered
# Active
# WHO Region
